# %%
# import necessary libraries

import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor
# Out:
# C:\Users\ryzen5\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
df = pd.read_csv('cox_2_bioactdata_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %%
# Data preprocessing 
X.shape
# Out:
# (4377, 881)

# %%
# remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(0.8*(1-0.8)))
X = selection.fit_transform(X)
X.shape
# Out:
# (4377, 180)

# %%
# train test split into 80:20
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
train,test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|██████████| 42/42 [00:46<00:00,  1.11s/it]

# %%
# Performance table of the training set (80% subset)
train
# Out:
#                                      Adjusted R-Squared  \
# Model
# HistGradientBoostingRegressor                      0.31
# LGBMRegressor                                      0.31
# RandomForestRegressor                              0.30
# XGBRegressor                                       0.29
# SVR                                                0.26
# NuSVR                                              0.26
# BaggingRegressor                                   0.24
# MLPRegressor                                       0.20
# KNeighborsRegressor                                0.19
# GradientBoostingRegressor                          0.15
# RidgeCV                                            0.08
# Ridge                                              0.08
# LinearRegression                                   0.08
# TransformedTargetRegressor                         0.08
# SGDRegressor                                       0.08
# ElasticNetCV                                       0.07
# LassoCV                                            0.07
# LassoLarsCV                                        0.07
# LassoLarsIC                                        0.07
# BayesianRidge                                      0.07
# HuberRegressor                                     0.06
# LinearSVR                                          0.04
# PoissonRegressor                                   0.02
# ExtraTreesRegressor                                0.02
# ExtraTreeRegressor                                -0.01
# OrthogonalMatchingPursuit                         -0.01
# OrthogonalMatchingPursuitCV                       -0.01
# DecisionTreeRegressor                             -0.01
# GammaRegressor                                    -0.03
# GeneralizedLinearRegressor                        -0.03
# TweedieRegressor                                  -0.03
# AdaBoostRegressor                                 -0.06
# Lasso                                             -0.26
# ElasticNet                                        -0.26
# DummyRegressor                                    -0.26
# LassoLars                                         -0.26
# PassiveAggressiveRegressor                        -0.43
# LarsCV                                            -2.99
# GaussianProcessRegressor                         -13.21
# KernelRidge                                      -22.90
# Lars                                            -147.36
# RANSACRegressor               -479899676935829848064.00
#
#                                               R-Squared           RMSE  \
# Model
# HistGradientBoostingRegressor                      0.45           1.01
# LGBMRegressor                                      0.45           1.01
# RandomForestRegressor                              0.45           1.01
# XGBRegressor                                       0.43           1.03
# SVR                                                0.41           1.05
# NuSVR                                              0.41           1.05
# BaggingRegressor                                   0.40           1.06
# MLPRegressor                                       0.36           1.09
# KNeighborsRegressor                                0.36           1.09
# GradientBoostingRegressor                          0.33           1.12
# RidgeCV                                            0.27           1.16
# Ridge                                              0.27           1.16
# LinearRegression                                   0.27           1.17
# TransformedTargetRegressor                         0.27           1.17
# SGDRegressor                                       0.27           1.17
# ElasticNetCV                                       0.27           1.17
# LassoCV                                            0.26           1.17
# LassoLarsCV                                        0.26           1.17
# LassoLarsIC                                        0.26           1.17
# BayesianRidge                                      0.26           1.17
# HuberRegressor                                     0.25           1.18
# LinearSVR                                          0.24           1.19
# PoissonRegressor                                   0.22           1.20
# ExtraTreesRegressor                                0.22           1.21
# ExtraTreeRegressor                                 0.20           1.22
# OrthogonalMatchingPursuit                          0.20           1.22
# OrthogonalMatchingPursuitCV                        0.20           1.22
# DecisionTreeRegressor                              0.19           1.22
# GammaRegressor                                     0.18           1.24
# GeneralizedLinearRegressor                         0.18           1.24
# TweedieRegressor                                   0.18           1.24
# AdaBoostRegressor                                  0.16           1.25
# Lasso                                             -0.00           1.37
# ElasticNet                                        -0.00           1.37
# DummyRegressor                                    -0.00           1.37
# LassoLars                                         -0.00           1.37
# PassiveAggressiveRegressor                        -0.13           1.45
# LarsCV                                            -2.17           2.43
# GaussianProcessRegressor                         -10.29           4.58
# KernelRidge                                      -17.98           5.94
# Lars                                            -116.84          14.80
# RANSACRegressor               -381177457680459169792.00 26625703366.30
#
#                                Time Taken
# Model
# HistGradientBoostingRegressor        4.45
# LGBMRegressor                        0.18
# RandomForestRegressor                4.20
# XGBRegressor                         0.55
# SVR                                  2.28
# NuSVR                                1.80
# BaggingRegressor                     0.51
# MLPRegressor                         6.73
# KNeighborsRegressor                  0.66
# GradientBoostingRegressor            1.52
# RidgeCV                              0.15
# Ridge                                0.05
# LinearRegression                     0.10
# TransformedTargetRegressor           0.09
# SGDRegressor                         0.09
# ElasticNetCV                         3.52
# LassoCV                              3.51
# LassoLarsCV                          0.36
# LassoLarsIC                          0.10
# BayesianRidge                        0.13
# HuberRegressor                       0.48
# LinearSVR                            1.13
# PoissonRegressor                     0.07
# ExtraTreesRegressor                  5.86
# ExtraTreeRegressor                   0.10
# OrthogonalMatchingPursuit            0.04
# OrthogonalMatchingPursuitCV          0.12
# DecisionTreeRegressor                0.10
# GammaRegressor                       0.05
# GeneralizedLinearRegressor           0.05
# TweedieRegressor                     0.05
# AdaBoostRegressor                    1.07
# Lasso                                0.04
# ElasticNet                           0.05
# DummyRegressor                       0.31
# LassoLars                            0.04
# PassiveAggressiveRegressor           0.06
# LarsCV                               0.44
# GaussianProcessRegressor             3.07
# KernelRidge                          0.51
# Lars                                 0.10
# RANSACRegressor                      1.99

# %%
# Performance table of the test set (20% subset)
test
# Out:
#                                      Adjusted R-Squared  \
# Model
# HistGradientBoostingRegressor                      0.31
# LGBMRegressor                                      0.31
# RandomForestRegressor                              0.30
# XGBRegressor                                       0.29
# SVR                                                0.26
# NuSVR                                              0.26
# BaggingRegressor                                   0.24
# MLPRegressor                                       0.20
# KNeighborsRegressor                                0.19
# GradientBoostingRegressor                          0.15
# RidgeCV                                            0.08
# Ridge                                              0.08
# LinearRegression                                   0.08
# TransformedTargetRegressor                         0.08
# SGDRegressor                                       0.08
# ElasticNetCV                                       0.07
# LassoCV                                            0.07
# LassoLarsCV                                        0.07
# LassoLarsIC                                        0.07
# BayesianRidge                                      0.07
# HuberRegressor                                     0.06
# LinearSVR                                          0.04
# PoissonRegressor                                   0.02
# ExtraTreesRegressor                                0.02
# ExtraTreeRegressor                                -0.01
# OrthogonalMatchingPursuit                         -0.01
# OrthogonalMatchingPursuitCV                       -0.01
# DecisionTreeRegressor                             -0.01
# GammaRegressor                                    -0.03
# GeneralizedLinearRegressor                        -0.03
# TweedieRegressor                                  -0.03
# AdaBoostRegressor                                 -0.06
# Lasso                                             -0.26
# ElasticNet                                        -0.26
# DummyRegressor                                    -0.26
# LassoLars                                         -0.26
# PassiveAggressiveRegressor                        -0.43
# LarsCV                                            -2.99
# GaussianProcessRegressor                         -13.21
# KernelRidge                                      -22.90
# Lars                                            -147.36
# RANSACRegressor               -479899676935829848064.00
#
#                                               R-Squared           RMSE  \
# Model
# HistGradientBoostingRegressor                      0.45           1.01
# LGBMRegressor                                      0.45           1.01
# RandomForestRegressor                              0.45           1.01
# XGBRegressor                                       0.43           1.03
# SVR                                                0.41           1.05
# NuSVR                                              0.41           1.05
# BaggingRegressor                                   0.40           1.06
# MLPRegressor                                       0.36           1.09
# KNeighborsRegressor                                0.36           1.09
# GradientBoostingRegressor                          0.33           1.12
# RidgeCV                                            0.27           1.16
# Ridge                                              0.27           1.16
# LinearRegression                                   0.27           1.17
# TransformedTargetRegressor                         0.27           1.17
# SGDRegressor                                       0.27           1.17
# ElasticNetCV                                       0.27           1.17
# LassoCV                                            0.26           1.17
# LassoLarsCV                                        0.26           1.17
# LassoLarsIC                                        0.26           1.17
# BayesianRidge                                      0.26           1.17
# HuberRegressor                                     0.25           1.18
# LinearSVR                                          0.24           1.19
# PoissonRegressor                                   0.22           1.20
# ExtraTreesRegressor                                0.22           1.21
# ExtraTreeRegressor                                 0.20           1.22
# OrthogonalMatchingPursuit                          0.20           1.22
# OrthogonalMatchingPursuitCV                        0.20           1.22
# DecisionTreeRegressor                              0.19           1.22
# GammaRegressor                                     0.18           1.24
# GeneralizedLinearRegressor                         0.18           1.24
# TweedieRegressor                                   0.18           1.24
# AdaBoostRegressor                                  0.16           1.25
# Lasso                                             -0.00           1.37
# ElasticNet                                        -0.00           1.37
# DummyRegressor                                    -0.00           1.37
# LassoLars                                         -0.00           1.37
# PassiveAggressiveRegressor                        -0.13           1.45
# LarsCV                                            -2.17           2.43
# GaussianProcessRegressor                         -10.29           4.58
# KernelRidge                                      -17.98           5.94
# Lars                                            -116.84          14.80
# RANSACRegressor               -381177457680459169792.00 26625703366.30
#
#                                Time Taken
# Model
# HistGradientBoostingRegressor        4.45
# LGBMRegressor                        0.18
# RandomForestRegressor                4.20
# XGBRegressor                         0.55
# SVR                                  2.28
# NuSVR                                1.80
# BaggingRegressor                     0.51
# MLPRegressor                         6.73
# KNeighborsRegressor                  0.66
# GradientBoostingRegressor            1.52
# RidgeCV                              0.15
# Ridge                                0.05
# LinearRegression                     0.10
# TransformedTargetRegressor           0.09
# SGDRegressor                         0.09
# ElasticNetCV                         3.52
# LassoCV                              3.51
# LassoLarsCV                          0.36
# LassoLarsIC                          0.10
# BayesianRidge                        0.13
# HuberRegressor                       0.48
# LinearSVR                            1.13
# PoissonRegressor                     0.07
# ExtraTreesRegressor                  5.86
# ExtraTreeRegressor                   0.10
# OrthogonalMatchingPursuit            0.04
# OrthogonalMatchingPursuitCV          0.12
# DecisionTreeRegressor                0.10
# GammaRegressor                       0.05
# GeneralizedLinearRegressor           0.05
# TweedieRegressor                     0.05
# AdaBoostRegressor                    1.07
# Lasso                                0.04
# ElasticNet                           0.05
# DummyRegressor                       0.31
# LassoLars                            0.04
# PassiveAggressiveRegressor           0.06
# LarsCV                               0.44
# GaussianProcessRegressor             3.07
# KernelRidge                          0.51
# Lars                                 0.10
# RANSACRegressor                      1.99

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
